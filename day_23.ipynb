# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars=pd.read_csv(r"C:\Users\Deekshith\Desktop\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.head(10)
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149
# 5  70  45.696322   89  113.185353  29.591768
# 6  55  50.013401   92  105.461264  30.308480
# 7  62  46.716554   50  102.598513  15.847758
# 8  62  46.716554   50  102.598513  16.359484
# 9  80  42.299078   94  115.645204  30.920154

# %%
cars.sample(10)
# Out:
#      HP        MPG  VOL          SP         WT
# 52  115  29.629936  124  120.404312  40.398164
# 10   73  44.652834   89  111.185353  29.363341
# 57  115  29.629936  101  118.288996  32.734518
# 60  145  27.354265  111  130.208698  36.888153
# 66  165  23.103172  114  132.484609  37.979956
# 0    49  53.700681   89  104.185353  28.762059
# 33  102  36.285456  113  121.392639  37.573290
# 70  280  19.678507   50  164.598513  15.823060
# 13   73  44.652834   89  111.185353  29.378436
# 1    55  50.013401   92  105.461264  30.466833

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.shape
# Out:
# (81, 5)

# %%
#EDA

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(cars['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x=cars['HP'],color='pink')
plt.show()

# %%
sns.distplot(x=cars['MPG'],color='YELLOW')
plt.show()

# %%
sns.distplot(x=cars['VOL'],color='RED')
plt.show()

# %%
sns.distplot(x=cars['WT'],color='PURPLE')
plt.title('Distribution of weight of vehicles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.distplot(x=cars['SP'],color='Green')
plt.show()

# %%
sns.boxplot(x=cars['MPG'],color='GREEN')
plt.show()

# %%
sns.boxplot(x=cars['HP'],color='PINK')
plt.show()

# %%
sns.boxplot(x=cars['WT'],color='RED')
plt.show()

# %%
sns.boxplot(x=cars['VOL'],color='YELLOW')
plt.show()

# %%
sns.boxplot(x=cars['HP'],color='purple')
plt.show()

# %%
from seaborn import scatterplot
scatterplot(x=cars['VOL'],y=cars['MPG'],color='RED')
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['SP'],y=cars['MPG'],color='PURPLE')
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
scatterplot(x=cars['WT'],y=cars['MPG'],color='GREEN')
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['MPG'],color='BLACK')
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.heatmap(cars.corr())
# Out:
# <Axes: >

# %%
sns.barplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
import seaborn as sns

# %%
scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
scatterplot(x=cars['SP'],y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>
